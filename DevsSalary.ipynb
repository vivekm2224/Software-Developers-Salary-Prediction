# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekm2224/Software-Developers-Salary-Prediction/blob/main/DevsSalary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/dataset/Salary.csv"

# %%
df=pd.read_csv(path)

# %%
df.isnull().sum()
# Out:
# ResponseId                            0
# Q120                                  0
# MainBranch                            0
# Age                                   0
# Employment                         1286
# RemoteWork                        15374
# CodingActivities                  15420
# EdLevel                            1211
# YearsCode                          1749
# YearsCodePro                      23048
# DevType                           12312
# OrgSize                           24141
# Country                            1211
# LanguageHaveWorkedWith             2044
# DatabaseHaveWorkedWith            15749
# WebframeHaveWorkedWith            22246
# MiscTechHaveWorkedWith            32165
# ToolsTechHaveWorkedWith           11300
# NEWCollabToolsHaveWorkedWith       3320
# OpSysPersonal use                  2627
# OpSysProfessional use             10597
# OfficeStackAsyncHaveWorkedWith    20094
# OfficeStackSyncHaveWorkedWith      5745
# AISearchHaveWorkedWith            32856
# AIDevHaveWorkedWith               63280
# TBranch                           23416
# WorkExp                           45605
# ProfessionalTech                  47401
# Industry                          52410
# ConvertedCompYearly               41165
# dtype: int64

# %%
df = df.dropna(subset=['ConvertedCompYearly'])


print(df.isnull().sum())
# Out:
# ResponseId                            0
# Q120                                  0
# MainBranch                            0
# Age                                   0
# Employment                           12
# RemoteWork                           79
# CodingActivities                    101
# EdLevel                               0
# YearsCode                            69
# YearsCodePro                        194
# DevType                             115
# OrgSize                              37
# Country                               0
# LanguageHaveWorkedWith              136
# DatabaseHaveWorkedWith             6255
# WebframeHaveWorkedWith            10154
# MiscTechHaveWorkedWith            16250
# ToolsTechHaveWorkedWith            3964
# NEWCollabToolsHaveWorkedWith        584
# OpSysPersonal use                   485
# OpSysProfessional use              2989
# OfficeStackAsyncHaveWorkedWith     6020
# OfficeStackSyncHaveWorkedWith      1004
# AISearchHaveWorkedWith            18534
# AIDevHaveWorkedWith               34079
# TBranch                            1863
# WorkExp                           15381
# ProfessionalTech                  16293
# Industry                          20272
# ConvertedCompYearly                   0
# dtype: int64

# %%
print(df.shape)
# Out:
# (48019, 30)

# %%
df.head(100)
# Out:
#     ResponseId     Q120                      MainBranch              Age  \
# 0            1  I agree                   None of these  18-24 years old
# 1            2  I agree  I am a developer by profession  25-34 years old
# 2            3  I agree  I am a developer by profession  45-54 years old
# 3            4  I agree  I am a developer by profession  25-34 years old
# 4            5  I agree  I am a developer by profession  25-34 years old
# ..         ...      ...                             ...              ...
# 95          96  I agree  I am a developer by profession  18-24 years old
# 96          97  I agree  I am a developer by profession  25-34 years old
# 97          98  I agree  I am a developer by profession  25-34 years old
# 98          99  I agree  I am a developer by profession  35-44 years old
# 99         100  I agree  I am a developer by profession  25-34 years old
#
#                                            Employment  \
# 0                                                 NaN
# 1                                 Employed, full-time
# 2                                 Employed, full-time
# 3                                 Employed, full-time
# 4   Employed, full-time;Independent contractor, fr...
# ..                                                ...
# 95                                Employed, full-time
# 96                                Employed, full-time
# 97                                Employed, full-time
# 98             Employed, part-time;Student, part-time
# 99  Employed, full-time;Independent contractor, fr...
#
#                               RemoteWork  \
# 0                                    NaN
# 1                                 Remote
# 2   Hybrid (some remote, some in-person)
# 3   Hybrid (some remote, some in-person)
# 4                                 Remote
# ..                                   ...
# 95                             In-person
# 96  Hybrid (some remote, some in-person)
# 97                             In-person
# 98  Hybrid (some remote, some in-person)
# 99                             In-person
#
#                                      CodingActivities  \
# 0                                                 NaN
# 1   Hobby;Contribute to open-source projects;Boots...
# 2   Hobby;Professional development or self-paced l...
# 3                                               Hobby
# 4   Hobby;Contribute to open-source projects;Profe...
# ..                                                ...
# 95  Hobby;Professional development or self-paced l...
# 96                                              Hobby
# 97                                              Hobby
# 98           Hobby;Contribute to open-source projects
# 99                      Hobby;Freelance/contract work
#
#                                               EdLevel YearsCode YearsCodePro  \
# 0                                                 NaN       NaN          NaN
# 1        Bachelor’s degree (B.A., B.S., B.Eng., etc.)        18            9
# 2        Bachelor’s degree (B.A., B.S., B.Eng., etc.)        27           23
# 3        Bachelor’s degree (B.A., B.S., B.Eng., etc.)        12            7
# 4        Bachelor’s degree (B.A., B.S., B.Eng., etc.)         6            4
# ..                                                ...       ...          ...
# 95       Bachelor’s degree (B.A., B.S., B.Eng., etc.)         6            2
# 96       Bachelor’s degree (B.A., B.S., B.Eng., etc.)        12            6
# 97  Some college/university study without earning ...        10            5
# 98       Bachelor’s degree (B.A., B.S., B.Eng., etc.)        20          NaN
# 99    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)        12            8
#
#     ...                            OpSysProfessional use  \
# 0   ...                                              NaN
# 1   ...  MacOS;Windows;Windows Subsystem for Linux (WSL)
# 2   ...                          MacOS;Other Linux-based
# 3   ...                                 iOS;iPadOS;MacOS
# 4   ...                          Other (Please Specify):
# ..  ...                                              ...
# 95  ...                                              NaN
# 96  ...                         iOS;MacOS;Ubuntu;Windows
# 97  ...                                           Ubuntu
# 98  ...                                          Windows
# 99  ...                        Debian;iOS;Ubuntu;Windows
#
#                        OfficeStackAsyncHaveWorkedWith  \
# 0                                                 NaN
# 1   Asana;Basecamp;GitHub Discussions;Jira;Linear;...
# 2              Markdown File;Stack Overflow for Teams
# 3                                                Jira
# 4                              Confluence;Jira;Notion
# ..                                                ...
# 95                                                NaN
# 96  Asana;Azure Devops;Confluence;GitHub Discussio...
# 97                                           YouTrack
# 98                                    Confluence;Jira
# 99                            Asana;Monday.com;Trello
#
#                         OfficeStackSyncHaveWorkedWith AISearchHaveWorkedWith  \
# 0                                                 NaN                    NaN
# 1   Cisco Webex Teams;Discord;Google Chat;Google M...                ChatGPT
# 2                          Microsoft Teams;Slack;Zoom                    NaN
# 3      Discord;Google Meet;Microsoft Teams;Slack;Zoom                    NaN
# 4                      Discord;Google Meet;Slack;Zoom                ChatGPT
# ..                                                ...                    ...
# 95                                           Telegram                ChatGPT
# 96  Google Chat;Google Meet;Signal;Skype;Slack;Wha...        Bing AI;ChatGPT
# 97                    Discord;Jitsi;Telegram;Whatsapp                    NaN
# 98                                    Microsoft Teams                Bing AI
# 99     Discord;Google Meet;Microsoft Teams;Skype;Zoom        Bing AI;ChatGPT
#
#    AIDevHaveWorkedWith TBranch WorkExp  \
# 0                  NaN     NaN     NaN
# 1       GitHub Copilot     Yes    10.0
# 2                  NaN     Yes    23.0
# 3                  NaN     Yes     7.0
# 4                  NaN     Yes     6.0
# ..                 ...     ...     ...
# 95                 NaN      No     NaN
# 96                 NaN     Yes     6.0
# 97                 NaN     Yes     5.0
# 98                 NaN     NaN     NaN
# 99                 NaN     Yes    12.0
#
#                                      ProfessionalTech  \
# 0                                                 NaN
# 1   DevOps function;Microservices;Automated testin...
# 2   DevOps function;Microservices;Automated testin...
# 3   Automated testing;Continuous integration (CI) ...
# 4   Microservices;Automated testing;Observability ...
# ..                                                ...
# 95                                                NaN
# 96  DevOps function;Microservices;Automated testin...
# 97                                    DevOps function
# 98                                                NaN
# 99    Microservices;Observability tools;None of these
#
#                                              Industry ConvertedCompYearly
# 0                                                 NaN                 NaN
# 1   Information Services, IT, Software Development...            285000.0
# 2   Information Services, IT, Software Development...            250000.0
# 3                                                 NaN            156000.0
# 4                                               Other             23456.0
# ..                                                ...                 ...
# 95                                                NaN               371.0
# 96                       Retail and Consumer Services             86528.0
# 97  Information Services, IT, Software Development...                 NaN
# 98                                                NaN                 NaN
# 99                       Retail and Consumer Services             30842.0
#
# [100 rows x 30 columns]
# Warning: Total number of columns (30) exceeds max_columns (20) limiting to first (20) columns.

# %%
df.isnull().sum()
# Out:
# ResponseId                            0
# Q120                                  0
# MainBranch                            0
# Age                                   0
# Employment                           12
# RemoteWork                           79
# CodingActivities                    101
# EdLevel                               0
# YearsCode                            69
# YearsCodePro                        194
# DevType                             115
# OrgSize                              37
# Country                               0
# LanguageHaveWorkedWith              136
# DatabaseHaveWorkedWith             6255
# WebframeHaveWorkedWith            10154
# MiscTechHaveWorkedWith            16250
# ToolsTechHaveWorkedWith            3964
# NEWCollabToolsHaveWorkedWith        584
# OpSysPersonal use                   485
# OpSysProfessional use              2989
# OfficeStackAsyncHaveWorkedWith     6020
# OfficeStackSyncHaveWorkedWith      1004
# AISearchHaveWorkedWith            18534
# AIDevHaveWorkedWith               34079
# TBranch                            1863
# WorkExp                           15381
# ProfessionalTech                  16293
# Industry                          20272
# ConvertedCompYearly                   0
# dtype: int64

# %%
df = df.dropna(subset=['Country'])


print(df.isnull().sum())
# Out:
# ResponseId                            0
# Q120                                  0
# MainBranch                            0
# Age                                   0
# Employment                           12
# RemoteWork                           79
# CodingActivities                    101
# EdLevel                               0
# YearsCode                            69
# YearsCodePro                        194
# DevType                             115
# OrgSize                              37
# Country                               0
# LanguageHaveWorkedWith              136
# DatabaseHaveWorkedWith             6255
# WebframeHaveWorkedWith            10154
# MiscTechHaveWorkedWith            16250
# ToolsTechHaveWorkedWith            3964
# NEWCollabToolsHaveWorkedWith        584
# OpSysPersonal use                   485
# OpSysProfessional use              2989
# OfficeStackAsyncHaveWorkedWith     6020
# OfficeStackSyncHaveWorkedWith      1004
# AISearchHaveWorkedWith            18534
# AIDevHaveWorkedWith               34079
# TBranch                            1863
# WorkExp                           15381
# ProfessionalTech                  16293
# Industry                          20272
# ConvertedCompYearly                   0
# dtype: int64

# %%
df = df.sort_values(by='Country')

# %%
df.head(5)
# Out:
#        ResponseId     Q120                      MainBranch  \
# 57361       57362  I agree  I am a developer by profession
# 37955       37956  I agree  I am a developer by profession
# 36048       36049  I agree  I am a developer by profession
# 41678       41679  I agree  I am a developer by profession
# 17872       17873  I agree  I am a developer by profession
#
#                       Age           Employment  \
# 57361     18-24 years old  Employed, full-time
# 37955     18-24 years old  Employed, full-time
# 36048     25-34 years old  Employed, full-time
# 41678  Under 18 years old  Employed, full-time
# 17872     25-34 years old  Employed, part-time
#
#                                  RemoteWork  \
# 57361  Hybrid (some remote, some in-person)
# 37955                                Remote
# 36048                             In-person
# 41678  Hybrid (some remote, some in-person)
# 17872  Hybrid (some remote, some in-person)
#
#                                         CodingActivities  \
# 57361                            Freelance/contract work
# 37955  Hobby;Professional development or self-paced l...
# 36048                     Hobby;Bootstrapping a business
# 41678                                              Hobby
# 17872  Hobby;Professional development or self-paced l...
#
#                                                  EdLevel           YearsCode  \
# 57361  Some college/university study without earning ...                   4
# 37955       Bachelor’s degree (B.A., B.S., B.Eng., etc.)                   4
# 36048       Bachelor’s degree (B.A., B.S., B.Eng., etc.)                   5
# 41678                          Primary/elementary school  More than 50 years
# 17872       Bachelor’s degree (B.A., B.S., B.Eng., etc.)                   3
#
#              YearsCodePro  ... OpSysProfessional use  \
# 57361                   3  ...        Ubuntu;Windows
# 37955                   3  ...                Ubuntu
# 36048                   2  ...                  Arch
# 41678  More than 50 years  ...               Red Hat
# 17872                   1  ...          MacOS;Ubuntu
#
#       OfficeStackAsyncHaveWorkedWith      OfficeStackSyncHaveWorkedWith  \
# 57361                           Jira                           Telegram
# 37955                         Trello                  Google Meet;Slack
# 36048                         Notion  Microsoft Teams;Telegram;Whatsapp
# 41678                        Clickup                              Jitsi
# 17872                           Jira             Telegram;Whatsapp;Zoom
#
#       AISearchHaveWorkedWith AIDevHaveWorkedWith TBranch WorkExp  \
# 57361                    NaN                 NaN     Yes     4.0
# 37955                ChatGPT                 NaN     Yes     4.0
# 36048                ChatGPT                 NaN     Yes     4.0
# 41678         Neeva AI;Phind      GitHub Copilot      No     NaN
# 17872                ChatGPT      GitHub Copilot     Yes     2.0
#
#                                         ProfessionalTech  \
# 57361                                      None of these
# 37955  DevOps function;Automated testing;Continuous i...
# 36048                                      None of these
# 41678                                                NaN
# 17872                      DevOps function;Microservices
#
#                                                 Industry ConvertedCompYearly
# 57361                                                NaN              2288.0
# 37955                                     Legal Services                41.0
# 36048                                     Legal Services               915.0
# 41678                                                NaN               648.0
# 17872  Information Services, IT, Software Development...              1144.0
#
# [5 rows x 30 columns]

# %%
df = df.dropna(subset=['YearsCodePro'])
df = df.rename({"ConvertedCompYearly": "Salary"}, axis=1)
print(df.isnull().sum())
df.to_csv('/content/drive/MyDrive/dataset/sorted_salary.csv', index=False)
# Out:
# ResponseId                            0
# Q120                                  0
# MainBranch                            0
# Age                                   0
# Employment                           12
# RemoteWork                           78
# CodingActivities                    100
# EdLevel                               0
# YearsCode                            25
# YearsCodePro                          0
# DevType                             102
# OrgSize                              28
# Country                               0
# LanguageHaveWorkedWith              128
# DatabaseHaveWorkedWith             6223
# WebframeHaveWorkedWith            10100
# MiscTechHaveWorkedWith            16164
# ToolsTechHaveWorkedWith            3916
# NEWCollabToolsHaveWorkedWith        574
# OpSysPersonal use                   470
# OpSysProfessional use              2949
# OfficeStackAsyncHaveWorkedWith     5962
# OfficeStackSyncHaveWorkedWith       977
# AISearchHaveWorkedWith            18443
# AIDevHaveWorkedWith               33930
# TBranch                            1845
# WorkExp                           15277
# ProfessionalTech                  16179
# Industry                          20155
# Salary                                0
# dtype: int64

# %%
path="/content/drive/MyDrive/dataset/sorted_salary.csv"

# %%
df=pd.read_csv(path)

# %%
df = df.rename({"ConvertedCompYearly": "Salary"}, axis=1)
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0        7715  I agree  I am a developer by profession  25-34 years old
# 1        8216  I agree  I am a developer by profession  35-44 years old
# 2       45793  I agree  I am a developer by profession  45-54 years old
# 3        7883  I agree  I am a developer by profession  25-34 years old
# 4        7479  I agree  I am a developer by profession  25-34 years old
#
#             Employment                            RemoteWork  \
# 0  Employed, full-time  Hybrid (some remote, some in-person)
# 1  Employed, full-time                                Remote
# 2  Employed, full-time                                Remote
# 3  Employed, full-time  Hybrid (some remote, some in-person)
# 4  Employed, full-time                                Remote
#
#                                     CodingActivities  EdLevel YearsCode  \
# 0  Hobby;Professional development or self-paced l...        3        10
# 1                                              Hobby        0        25
# 2                                              Hobby        0        43
# 3                                              Hobby        2        14
# 4  Hobby;Contribute to open-source projects;Boots...        1        13
#
#    YearsCodePro  ...                      OpSysProfessional use  \
# 0           4.0  ...  Windows;Windows Subsystem for Linux (WSL)
# 1          20.0  ...                             Ubuntu;Windows
# 2          22.0  ...                                      MacOS
# 3           2.0  ...                                      MacOS
# 4          10.0  ...                           iOS;iPadOS;MacOS
#
#                       OfficeStackAsyncHaveWorkedWith  \
# 0                                                NaN
# 1                                               Jira
# 2                      Confluence;Jira;Markdown File
# 3                                         Confluence
# 4  Airtable;Clickup;Confluence;Jira;Markdown File...
#
#                        OfficeStackSyncHaveWorkedWith  \
# 0  Cisco Webex Teams;Google Meet;Microsoft Teams;...
# 1                         Microsoft Teams;Slack;Zoom
# 2       Discord;Google Chat;Google Meet;Signal;Slack
# 3                                    Microsoft Teams
# 4             Google Meet;Microsoft Teams;Slack;Zoom
#
#                AISearchHaveWorkedWith AIDevHaveWorkedWith TBranch WorkExp  \
# 0                     Bing AI;ChatGPT                 NaN     Yes     2.0
# 1                                 NaN                 NaN      No     NaN
# 2  ChatGPT;Perplexity AI;WolframAlpha      GitHub Copilot      No     NaN
# 3                                 NaN                 NaN     Yes     2.0
# 4                             ChatGPT                 NaN     Yes    10.0
#
#                                     ProfessionalTech  \
# 0             DevOps function;Innersource initiative
# 1                                                NaN
# 2                                                NaN
# 3  DevOps function;Microservices;Automated testin...
# 4                                    DevOps function
#
#                                             Industry    Salary
# 0                                         Healthcare   66104.0
# 1                                                NaN   92545.0
# 2                                                NaN  105766.0
# 3                                 Financial Services   60816.0
# 4  Information Services, IT, Software Development...  118987.0
#
# [5 rows x 30 columns]

# %%
df["EdLevel"].unique()
# Out:
# array(['Some college/university study without earning a degree',
#        'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#        'Primary/elementary school',
#        'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#        'Professional degree (JD, MD, Ph.D, Ed.D, etc.)', 'Something else',
#        'Associate degree (A.A., A.S., etc.)'], dtype=object)

# %%
def edu(x):
    if 'Bachelor’s degree' in x:
        return 'Bachelor’s degree'
    if 'Master’s degree' in x:
        return 'Master’s degree'
    if 'Professional degree' in x or 'Other doctoral' in x:
        return 'Post grad'
    return 'Less than a Bachelors'

df['EdLevel'] = df['EdLevel'].apply(edu)

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0        7715  I agree  I am a developer by profession  25-34 years old
# 1        8216  I agree  I am a developer by profession  35-44 years old
# 2       45793  I agree  I am a developer by profession  45-54 years old
# 3        7883  I agree  I am a developer by profession  25-34 years old
# 4        7479  I agree  I am a developer by profession  25-34 years old
#
#             Employment                            RemoteWork  \
# 0  Employed, full-time  Hybrid (some remote, some in-person)
# 1  Employed, full-time                                Remote
# 2  Employed, full-time                                Remote
# 3  Employed, full-time  Hybrid (some remote, some in-person)
# 4  Employed, full-time                                Remote
#
#                                     CodingActivities  EdLevel YearsCode  \
# 0  Hobby;Professional development or self-paced l...        3        10
# 1                                              Hobby        0        25
# 2                                              Hobby        0        43
# 3                                              Hobby        2        14
# 4  Hobby;Contribute to open-source projects;Boots...        1        13
#
#    YearsCodePro  ...                      OpSysProfessional use  \
# 0           4.0  ...  Windows;Windows Subsystem for Linux (WSL)
# 1          20.0  ...                             Ubuntu;Windows
# 2          22.0  ...                                      MacOS
# 3           2.0  ...                                      MacOS
# 4          10.0  ...                           iOS;iPadOS;MacOS
#
#                       OfficeStackAsyncHaveWorkedWith  \
# 0                                                NaN
# 1                                               Jira
# 2                      Confluence;Jira;Markdown File
# 3                                         Confluence
# 4  Airtable;Clickup;Confluence;Jira;Markdown File...
#
#                        OfficeStackSyncHaveWorkedWith  \
# 0  Cisco Webex Teams;Google Meet;Microsoft Teams;...
# 1                         Microsoft Teams;Slack;Zoom
# 2       Discord;Google Chat;Google Meet;Signal;Slack
# 3                                    Microsoft Teams
# 4             Google Meet;Microsoft Teams;Slack;Zoom
#
#                AISearchHaveWorkedWith AIDevHaveWorkedWith TBranch WorkExp  \
# 0                     Bing AI;ChatGPT                 NaN     Yes     2.0
# 1                                 NaN                 NaN      No     NaN
# 2  ChatGPT;Perplexity AI;WolframAlpha      GitHub Copilot      No     NaN
# 3                                 NaN                 NaN     Yes     2.0
# 4                             ChatGPT                 NaN     Yes    10.0
#
#                                     ProfessionalTech  \
# 0             DevOps function;Innersource initiative
# 1                                                NaN
# 2                                                NaN
# 3  DevOps function;Microservices;Automated testin...
# 4                                    DevOps function
#
#                                             Industry    Salary
# 0                                         Healthcare   66104.0
# 1                                                NaN   92545.0
# 2                                                NaN  105766.0
# 3                                 Financial Services   60816.0
# 4  Information Services, IT, Software Development...  118987.0
#
# [5 rows x 30 columns]

# %%
df["EdLevel"].unique()
# Out:
# array([3, 0, 2, 1])

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                11847
# Germany                                                  3947
# United Kingdom of Great Britain and Northern Ireland     3522
# Canada                                                   2095
# India                                                    1850
#                                                         ...
# Lesotho                                                     1
# Saint Vincent and the Grenadines                            1
# Saint Kitts and Nevis                                       1
# Mauritania                                                  1
# Liechtenstein                                               1
# Name: count, Length: 171, dtype: int64

# %%
def simplify(categories, cutoff):
    ans = {}
    for i in range(len(categories)):
        if categories.values[i] >= cutoff:
            ans[categories.index[i]] = categories.index[i]
        else:
            ans[categories.index[i]] = 'Other'
    return ans

# %%
country_map = simplify(df.Country.value_counts(), 400)
df['Country'] = df['Country'].map(country_map)
df.Country.value_counts()
# Out:
# Country
# United States of America                                11847
# Other                                                    8310
# Germany                                                  3947
# United Kingdom of Great Britain and Northern Ireland     3522
# Canada                                                   2095
# India                                                    1850
# France                                                   1793
# Netherlands                                              1359
# Poland                                                   1265
# Brazil                                                   1249
# Australia                                                1206
# Spain                                                    1142
# Sweden                                                   1055
# Italy                                                    1010
# Switzerland                                               660
# Austria                                                   531
# Denmark                                                   516
# Czech Republic                                            492
# Norway                                                    484
# Portugal                                                  478
# Israel                                                    469
# Belgium                                                   445
# Finland                                                   440
# Russian Federation                                        424
# Ukraine                                                   417
# New Zealand                                               412
# Romania                                                   407
# Name: count, dtype: int64

# %%
df = df[["Country", "EdLevel", "YearsCodePro", "Salary"]]

# %%
df['YearsCodePro'].unique()
# Out:
# array(['3', '2', 'More than 50 years', '1', '10', '6', 'Less than 1 year',
#        '4', '9', '5', '26', '8', '25', '23', '18', '15', '22', '30', '20',
#        '7', '13', '12', '11', '16', '33', '31', '24', '35', '14', '17',
#        '28', '27', '32', '37', '21', '19', '40', '44', '36', '39', '38',
#        '34', '42', '41', '46', '43', '50', '29', '45', '48', '47', '49'],
#       dtype=object)

# %%
def exp(x):
    if x ==  'More than 50 years':
        return 51
    if x == 'Less than 1 year':
        return 0.5
    return float(x)

df['YearsCodePro'] = df['YearsCodePro'].apply(exp)

df['YearsCodePro'].unique()
# Out:
# array([ 3. ,  2. , 51. ,  1. , 10. ,  6. ,  0.5,  4. ,  9. ,  5. , 26. ,
#         8. , 25. , 23. , 18. , 15. , 22. , 30. , 20. ,  7. , 13. , 12. ,
#        11. , 16. , 33. , 31. , 24. , 35. , 14. , 17. , 28. , 27. , 32. ,
#        37. , 21. , 19. , 40. , 44. , 36. , 39. , 38. , 34. , 42. , 41. ,
#        46. , 43. , 50. , 29. , 45. , 48. , 47. , 49. ])

# %%
from sklearn.preprocessing import LabelEncoder
edu = LabelEncoder()
df['EdLevel'] = edu.fit_transform(df['EdLevel'])
df['EdLevel'].unique()
# Out:
# array([3, 0, 2, 1])

# %%
df["Country"].unique()
# Out:
# array(['Other', 'Australia', 'Austria', 'Belgium', 'Brazil', 'Canada',
#        'Czech Republic', 'Denmark', 'Finland', 'France', 'Germany',
#        'India', 'Israel', 'Italy', 'Netherlands', 'New Zealand', 'Norway',
#        'Poland', 'Portugal', 'Romania', 'Russian Federation', 'Spain',
#        'Sweden', 'Switzerland', 'Ukraine',
#        'United Kingdom of Great Britain and Northern Ireland',
#        'United States of America'], dtype=object)

# %%
X = df.drop("Salary" , axis = 1)
y = df['Salary']

# %%
from sklearn.linear_model  import LinearRegression
linear_reg = LinearRegression()
linear_reg.fit(X , y.values)
# Out:
# LinearRegression()

# %%
y_pred = linear_reg.predict(X)

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error
import numpy as np
error = np.sqrt(mean_squared_error(y , y_pred))

# %%
from sklearn.tree import DecisionTreeRegressor

dtr = DecisionTreeRegressor(random_state = 0)
dtr.fit(X,y.values)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred = dtr.predict(X)

# %%
error = np.sqrt(mean_squared_error(y,y_pred))
print("${:,.02f}".format(error))
error
# Out:
# $34,794.87
# 34794.86884553668

# %%
# Define the columns to be merged
columns_to_merge = [
    'LanguageHaveWorkedWith', 'DatabaseHaveWorkedWith', 'WebframeHaveWorkedWith',
    'MiscTechHaveWorkedWith', 'ToolsTechHaveWorkedWith', 'NEWCollabToolsHaveWorkedWith',
    'OpSysPersonal use', 'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
    'OfficeStackSyncHaveWorkedWith', 'AISearchHaveWorkedWith'
]


df[columns_to_merge] = df[columns_to_merge].fillna('')


df['Skills'] = df[columns_to_merge].apply(lambda row: ';'.join(row.values.astype(str)), axis=1)


df['Skills'] = df['Skills'].apply(lambda x: ';'.join(sorted(set(x.split(';')))))


print(df[['Skills']].head())

df.drop(columns=columns_to_merge, inplace=True)



df.to_csv(path, index=False)

print(f"DataFrame saved to {path}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-28c584c6c052> in <cell line: 10>()
#       8
#       9
# ---> 10 df[columns_to_merge] = df[columns_to_merge].fillna('')
#      11
#      12
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5875             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5876
# -> 5877         self._raise_if_missing(keyarr, indexer, axis_name)
#    5878
#    5879         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5936                 if use_interval_msg:
#    5937                     key = list(key)
# -> 5938                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5939
#    5940             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['LanguageHaveWorkedWith', 'DatabaseHaveWorkedWith',\n       'WebframeHaveWorkedWith', 'MiscTechHaveWorkedWith',\n       'ToolsTechHaveWorkedWith', 'NEWCollabToolsHaveWorkedWith',\n       'OpSysPersonal use', 'OpSysProfessional use',\n       'OfficeStackAsyncHaveWorkedWith', 'OfficeStackSyncHaveWorkedWith',\n       'AISearchHaveWorkedWith'],\n      dtype='object')] are in the [columns]"

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0        7715  I agree  I am a developer by profession  25-34 years old
# 1        8216  I agree  I am a developer by profession  35-44 years old
# 2       45793  I agree  I am a developer by profession  45-54 years old
# 3        7883  I agree  I am a developer by profession  25-34 years old
# 4        7479  I agree  I am a developer by profession  25-34 years old
#
#             Employment                            RemoteWork  \
# 0  Employed, full-time  Hybrid (some remote, some in-person)
# 1  Employed, full-time                                Remote
# 2  Employed, full-time                                Remote
# 3  Employed, full-time  Hybrid (some remote, some in-person)
# 4  Employed, full-time                                Remote
#
#                                     CodingActivities  EdLevel YearsCode  \
# 0  Hobby;Professional development or self-paced l...        3        10
# 1                                              Hobby        0        25
# 2                                              Hobby        0        43
# 3                                              Hobby        2        14
# 4  Hobby;Contribute to open-source projects;Boots...        1        13
#
#    YearsCodePro                      DevType                   OrgSize  \
# 0           4.0  Research & Development role  5,000 to 9,999 employees
# 1          20.0          Engineering manager          2 to 9 employees
# 2          22.0        Developer, full-stack      100 to 499 employees
# 3           2.0          Developer, back-end  10,000 or more employees
# 4          10.0            Developer, mobile        10 to 19 employees
#
#    Country AIDevHaveWorkedWith TBranch  WorkExp  \
# 0        0                 NaN     Yes      2.0
# 1        0                 NaN      No      NaN
# 2        0      GitHub Copilot      No      NaN
# 3        0                 NaN     Yes      2.0
# 4        0                 NaN     Yes     10.0
#
#                                     ProfessionalTech  \
# 0             DevOps function;Innersource initiative
# 1                                                NaN
# 2                                                NaN
# 3  DevOps function;Microservices;Automated testin...
# 4                                    DevOps function
#
#                                             Industry    Salary  \
# 0                                         Healthcare   66104.0
# 1                                                NaN   92545.0
# 2                                                NaN  105766.0
# 3                                 Financial Services   60816.0
# 4  Information Services, IT, Software Development...  118987.0
#
#                                               Skills
# 0  ;Android;Angular;Apache Spark;Bing AI;C;C#;C++...
# 1  ;Android Studio;Bash/Shell (all shells);JavaSc...
# 2  ;BigQuery;ChatGPT;Confluence;Discord;Docker;Go...
# 3  ;Ansible;Apache Kafka;Bash/Shell (all shells);...
# 4  Airtable;Bash/Shell (all shells);ChatGPT;Click...

# %%
df.drop(columns='AIDevHaveWorkedWith', inplace=True)

df.to_csv(path, index=False)

print(f"DataFrame saved to {path}")
